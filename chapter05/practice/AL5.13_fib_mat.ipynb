# %% [markdown]
# # 문제 정의
# 반복 구조를 사용해 기술한 피보나치 수열

# %% [markdown]
# # 알고리즘 설명
# n이 2보다 작을경우 n값을 반환하고

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 알고리즘 코드
def fib_iter(n):
    if(n<2):return n
    last=0
    current=1
    for i in range(2,n+1):
        tmp=current
        current+=last
        last=tmp
    return current

# %%
# 테스트 코드
print(fib_iter(7))
# Out:
# 13
