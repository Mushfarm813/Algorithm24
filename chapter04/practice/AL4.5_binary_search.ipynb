# %% [markdown]
# # 문제설명
# 이진 탐색(순환구조)

# %% [markdown]
# # 알고리즘 설명
# 주어진 리스트에서 주어진 값을 순환 구조로 이진 탐색한다. 함수는 리스트를 절반으로 나누어 목표 값을 찾을 때까지 반복하며, 값을 찾으면 해당 인덱스를 반환하고 찾지 못하면 -1을 반환

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 코드개요
# 입력 변수 : [1, 3, 8, 13, 16, 21, 26, 27, 30, 33, 36, 39, 41, 44, 49]
#
# 출력 변수 : 리스트에 있는 키 값의 인텍스 (없으면 -1)
#
# 함수 설명 : 결과 10은 33이라는 숫자를 찾아냈을 때 표시된다. -1는 찾는 숫자가 없을 때 표시한다.

# %%
# 알고리즘 코드
def binary_search(A, key, low, high) :
    if (low <- high):
        mid = (low + high) // 2
    if key == A[mid] :
        return mid
    elif key < A[mid] :
        return binary_search(A, key, low, mid-1)
    else :
        return binary_search(A, key, mid+1, high)
    return -1

# %%
#테스트 코드
def binary_search(A, key, low, high):
    if (low <= high):
        mid = (low + high)
        if key == A[mid] :
            return mid
        elif key < A[mid] :
            return binary_search(A, key, low, mid-1)
        else :
            return binary_search(A, key, mid+1, high)
    return -1

listA = [1, 3, 8, 13, 13, 16, 21, 26, 27, 30, 33, 36, 39, 41, 44, 49]
print("입력 리스트 = ", listA)
print("33 탐색(순환) -->", binary_search(listA, 33, 0, len(listA)-1))
print("32 탐색(순환) -->", binary_search(listA, 32, 0, len(listA)-1))

# %% [markdown]
# 입력 리스트 =  [1, 3, 8, 13, 13, 16, 21, 26, 27, 30, 33, 36, 39, 41, 44, 49]
#
# 33 탐색(순환) --> 10
#
# 32 탐색(순환) --> -1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 복잡도 분석
# 시간 복잡도는 O(log n) 이다. 이진 탐색의 공간 복잡도는 순환 호출에 의해 소비되는 스택 공간에 따라 결정된다. 일반적으로 스택의 깊이는 이진 탐색을 수행하는 동안 최대 O(log n)이다.
#
# 시간복잡도는 O(n) 이고 공간 복잡도는 스택 공간에 의해 O(log n)이다.
